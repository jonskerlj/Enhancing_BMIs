# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Kalman filter Data
KF_R2_pos = [[0.6172143,  0.6058856,  0.60322373, 0.58746009, 0.60911152, 0.59725992, 0.60874164, 0.57356664, 0.47798814, 0.24384361]]
KF_R2_vel = [[0.62795252, 0.62651425, 0.63148993, 0.62669511, 0.61615621, 0.6077967,  0.61300454, 0.54525835, 0.54310651, 0.46998113]]

KF_R2_pos.append([0.60875975, 0.60675139, 0.59869358,0.60430106, 0.58407435, 0.58544427,  0.59950886, 0.5042158 , 0.48618324, 0.00535568])
KF_R2_vel.append([0.64017173, 0.62976355, 0.62695435, 0.63567135, 0.62968234, 0.58715673,  0.56865127, 0.61019115, 0.5220634,  0.27808821])

KF_R2_pos.append([0.59989508,  0.59328865,  0.58718805, 0.58630909,  0.5537204,   0.5533053, 0.56564954,  0.461939,   0.35732089, 0.02563526])
KF_R2_vel.append([0.63186103, 0.63803362, 0.64074356, 0.61826824, 0.60925901, 0.62104115, 0.61373982, 0.56575879, 0.57342781, 0.40099438])


KF_R2_pos.append([0.59074977,  0.57496116,  0.66088222,  0.68976875,  0.60090425,  0.57861655, 0.54407581,  0.62304218,  0.64064767, 0.00126827])
KF_R2_vel.append([0.61010422,  0.59526278,  0.56748674,  0.60403195,  0.55176562,  0.57264359, 0.61910301,  0.53076722,  0.54048395,  0.49433274])

KF_R2_pos.append([0.6010649,  0.61931833, 0.66875164, 0.65910261, 0.60237027, 0.56169137, 0.62106014, 0.62398177, 0.5908202,  0.30574805])
KF_R2_vel.append([0.56895224, 0.59091629, 0.5668695,  0.57649399, 0.54659267, 0.58273581, 0.60309278, 0.5408484,  0.49028314, 0.40803804])

KF_R2_pos = np.array(KF_R2_pos)
KF_R2_vel = np.array(KF_R2_vel)

KF_R2_pos_mean = np.mean(KF_R2_pos, axis=0)
KF_R2_pos_std = np.std(KF_R2_pos, axis=0)

KF_R2_vel_mean = np.mean(KF_R2_vel, axis=0)
KF_R2_vel_std = np.std(KF_R2_vel, axis=0)

# %%
## KF plot - position

x = [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]
R_ind_pos = np.array([0.374, 0.381, 0.403, 0.354, 0.364])
R_ind_pos_mean = np.mean(R_ind_pos)
R_ind_pos_std = np.std(R_ind_pos)


fig_KF_len=plt.figure()
plt.errorbar(x, KF_R2_pos_mean, yerr=KF_R2_pos_std, fmt='.k', capsize=3,label='baseline KF')
#plt.plot(x, ind, 'r',label='avg. ind. targets decoder')
plt.errorbar([12.5],R_ind_pos_mean, yerr=R_ind_pos_std, fmt='.r',capsize=3,label='direction-specific KF')
plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.grid()
plt.legend()
plt.savefig('RS_effect_of_data_length/KF_SR_data_length_pos.png')
plt.savefig('RS_effect_of_data_length/KF_SR_data_length_pos.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
## KF plot - velocity
R_ind_vel = np.array([0.376, 0.391, 0.416, 0.458, 0.447])
R_ind_vel_mean = np.mean(R_ind_vel)
R_ind_vel_std = np.std(R_ind_vel)


fig_KF_len=plt.figure()
plt.errorbar(x, KF_R2_vel_mean, yerr=KF_R2_vel_std, fmt='.k', capsize=3,label='baseline KF')
#plt.plot(x, ind, 'r',label='avg. ind. targets decoder')
plt.errorbar([12.5],R_ind_vel_mean, yerr=R_ind_vel_std, fmt='.r',capsize=3,label='direction-specific KF')
plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.grid()
plt.legend()
plt.savefig('RS_effect_of_data_length/KF_SR_data_length_vel.png')
plt.savefig('RS_effect_of_data_length/KF_SR_data_length_vel.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Wiener filter Data
WF_R2_pos = [[0.60209976,  0.57080926,  0.61290944,  0.67617706,  0.57822361,  0.57020854, 0.46818683,  0.52516328,  0.52126047, 0.12918008]]
WF_R2_vel = [[0.72373555,  0.73119994,  0.73593386,  0.75872913,  0.72874294,  0.71203632, 0.69839848,  0.66519704,  0.69371061,  0.5704323]]

WF_R2_pos.append([0.59273285,  0.61471975,  0.63568129,  0.64084619,  0.59436511,  0.53288546, 0.52381655,  0.55304771,  0.46239715, 0.32535825])
WF_R2_vel.append([0.72026085,  0.7362234,   0.74503839,  0.73519998,  0.72137064,  0.6956837,  0.68512562, 0.66968476,  0.63551291,  0.43687902])

WF_R2_pos.append([0.59989508,  0.59328865,  0.58718805, 0.58630909,  0.5537204,   0.5533053, 0.56564954,  0.461939,   0.35732089, 0.02563526])
WF_R2_vel.append([0.72234206,  0.72410052,  0.72509504,  0.71575966,  0.70558827,  0.70001796, 0.68375413,  0.62998486,  0.61810602,  0.35189033])


WF_R2_pos.append([0.59737365,  0.59198035,  0.58290003,  0.56035553,  0.56200064,  0.56303389,  0.52957605,  0.5014977,   0.48550888, 0.13245218])
WF_R2_vel.append([0.72840967,  0.7169718,   0.71578805,  0.72435534,  0.71506934,  0.6879633,  0.65363172,  0.676994,    0.63663837,  0.29578416])

WF_R2_pos.append([0.60728551,  0.59492381,  0.58288507,  0.56607975,  0.5723126,   0.56224772,  0.55748055,  0.52653603,  0.34947042, 0.21899183])
WF_R2_vel.append([0.71823091,  0.71777555,  0.71876244,  0.71778213,  0.708169,    0.6897895,  0.68344396,  0.63232062,  0.55356358,  0.3430979 ])

WF_R2_pos = np.array(WF_R2_pos)
WF_R2_vel = np.array(WF_R2_vel)

WF_R2_pos_mean = np.mean(WF_R2_pos, axis=0)
WF_R2_pos_std = np.std(WF_R2_pos, axis=0)

WF_R2_vel_mean = np.mean(WF_R2_vel, axis=0)
WF_R2_vel_std = np.std(WF_R2_vel, axis=0)

# %%
## WF plot - position

x = [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]
R_ind_pos = np.array([0.228, 0.318, 0.315, 0.281, 0.328])
R_ind_pos_mean = np.mean(R_ind_pos)
R_ind_pos_std = np.std(R_ind_pos)


fig_FF_len=plt.figure()
plt.errorbar(x, WF_R2_pos_mean, yerr=WF_R2_pos_std, fmt='.k', capsize=3,label='baseline WF')
#plt.plot(x, ind, 'r',label='avg. ind. targets decoder')
plt.errorbar([12.5],R_ind_pos_mean, yerr=R_ind_pos_std, fmt='.r',capsize=3,label='direction-specific WF')
plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.grid()
plt.legend(loc="lower right")
plt.savefig('RS_effect_of_data_length/WF_SR_data_length_pos.png')
plt.savefig('RS_effect_of_data_length/WF_SR_data_length_pos.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
## WF plot - velocity
R_ind_vel = np.array([0.385, 0.475, 0.532, 0.544, 0.402])
R_ind_vel_mean = np.mean(R_ind_vel)
R_ind_vel_std = np.std(R_ind_vel)


fig_FF_len=plt.figure()
plt.errorbar(x, WF_R2_vel_mean, yerr=WF_R2_vel_std, fmt='.k', capsize=3,label='baseline WF')
#plt.plot(x, ind, 'r',label='avg. ind. targets decoder')
plt.errorbar([12.5],R_ind_vel_mean, yerr=R_ind_vel_std, fmt='.r',capsize=3,label='direction-specific WF')
plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.grid()
plt.legend()
plt.savefig('RS_effect_of_data_length/WF_SR_data_length_vel.png')
plt.savefig('RS_effect_of_data_length/WF_SR_data_length_vel.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# FFNN Data
FF_R2_pos = [[0.62566004, 0.59393973, 0.60089459, 0.63122683, 0.619327,   0.60270948,  0.60037793, 0.56465377, 0.52854936, 0.4530982]]
FF_R2_vel = [[0.78155998, 0.76825137, 0.7655123,  0.76433825, 0.7648632,  0.77267797,  0.76971266, 0.75648495, 0.72121261, 0.68520864]]

FF_R2_pos.append([0.59388483, 0.6030336,  0.58091801, 0.6121316,  0.6014213,  0.62766461, 0.58300345, 0.54776005, 0.55015442, 0.46425779])
FF_R2_vel.append([0.77966139, 0.77648813, 0.79019632, 0.77272221, 0.74187133, 0.76357065, 0.76391974, 0.75999259, 0.72664834, 0.67491561])

FF_R2_pos.append([0.61572668, 0.60508582, 0.5838495,  0.55342104, 0.53211074, 0.55888372, 0.5410163,  0.55254847, 0.25053713, 0.1094079])
FF_R2_vel.append([0.80418, 0.78976449, 0.79136983, 0.7688036,  0.74511614, 0.74716327, 0.73705005, 0.74011635, 0.72513189, 0.6079126])


FF_R2_pos.append([0.60078505, 0.5700437,  0.54944553, 0.57163801, 0.49493322, 0.50453518, 0.52712345, 0.24294997, 0.19381601, 0.1017176])
FF_R2_vel.append([0.78292957, 0.765842,   0.79437068, 0.80398869, 0.78609571, 0.76316145, 0.76893071, 0.73130214, 0.67088435, 0.50317855])

FF_R2_pos.append([0.62640291, 0.58023843, 0.53529306, 0.70386241,  0.45499615,  0.47088043, 0.42490939, 0.65298944,  0.56843917, 0.22638899])
FF_R2_vel.append([0.77466274, 0.80377866,  0.78906747, 0.79023805,  0.78555693,  0.76158306, 0.77127522,  0.6739734,  0.80916125,  0.68321104])


FF_R2_pos = np.array(FF_R2_pos)
FF_R2_vel = np.array(FF_R2_vel)

FF_R2_pos_mean = np.mean(FF_R2_pos, axis=0)
FF_R2_pos_std = np.std(FF_R2_pos, axis=0)

FF_R2_vel_mean = np.mean(FF_R2_vel, axis=0)
FF_R2_vel_std = np.std(FF_R2_vel, axis=0)

# %%
## FFNN plot - position

x = [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]
R_ind_pos = np.array([0.396, 0.394, 0.441, 0.471, 0.452])
R_ind_pos_mean = np.mean(R_ind_pos)
R_ind_pos_std = np.std(R_ind_pos)


fig_FF_len=plt.figure()
plt.errorbar(x, FF_R2_pos_mean, yerr=FF_R2_pos_std, fmt='.k', capsize=3,label='baseline FFNN')
#plt.plot(x, ind, 'r',label='avg. ind. targets decoder')
plt.errorbar([12.5],R_ind_pos_mean, yerr=R_ind_pos_std, fmt='.r',capsize=3,label='direction-specific FFNN')
plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.grid()
plt.legend()
plt.savefig('RS_effect_of_data_length/FFNN_SR_data_length_pos.png')
plt.savefig('RS_effect_of_data_length/FFNN_SR_data_length_pos.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
## FFNN plot - velocity
R_ind_vel = np.array([0.594, 0.603, 0.645, 0.641, 0.647])
R_ind_vel_mean = np.mean(R_ind_vel)
R_ind_vel_std = np.std(R_ind_vel)


fig_FF_len=plt.figure()
plt.errorbar(x, FF_R2_vel_mean, yerr=FF_R2_vel_std, fmt='.k', capsize=3,label='baseline FFNN')
#plt.plot(x, ind, 'r',label='avg. ind. targets decoder')
plt.errorbar([12.5],R_ind_vel_mean, yerr=R_ind_vel_std, fmt='.r',capsize=3,label='direction-specific FFNN')
plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.grid()
plt.legend()
plt.savefig('RS_effect_of_data_length/FFNN_SR_data_length_vel.png')
plt.savefig('RS_effect_of_data_length/FFNN_SR_data_length_vel.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
## LSTM Data
LS_R2_pos = [[0.5749833,  0.57636465, 0.61249013, 0.61750718, 0.59482529, 0.60015756,  0.58042,    0.56742827,0.52411642, 0.47162856]]
LS_R2_vel = [[0.79458516, 0.80000756, 0.79611655, 0.78997592, 0.78584025, 0.77942839,  0.76153995, 0.74821273, 0.71544917, 0.61532291]]

LS_R2_pos.append([0.61204807, 0.57088926, 0.60609292, 0.62636808, 0.61141145, 0.60900607,  0.57454509, 0.5548219,  0.53432302, 0.46411554])
LS_R2_vel.append([0.80952073, 0.7898495,  0.80013489, 0.79197068, 0.77795733, 0.77229612,  0.77500517, 0.744414,   0.72840122, 0.62100231])

LS_R2_pos.append([0.63341894, 0.63559793, 0.6181785,  0.5894747,  0.58697264, 0.60887423,  0.59537745, 0.53404739, 0.51140073, 0.24835519])
LS_R2_vel.append([0.80070159, 0.78340005, 0.77409942, 0.76340955, 0.76640404, 0.74483507,  0.72091981, 0.73604912, 0.69785304, 0.51603553])

LS_R2_pos.append([0.63880331, 0.62950018, 0.63839928, 0.62167472, 0.62749602, 0.58490052, 0.56134897, 0.52954638, 0.50736986, 0.03812039])
LS_R2_vel.append([0.80796897, 0.78212433, 0.78819595, 0.76981578, 0.75240493, 0.71718951, 0.71228038, 0.75446223, 0.70719769, 0.53281066])

LS_R2_pos.append([0.59421605,  0.61380202,  0.61670206,  0.61127345,  0.58142116,  0.58610445, 0.60682405,  0.49720077,  0.40399494, 0.15025238])
LS_R2_vel.append([0.79281126,  0.79445071,  0.79091602,  0.76297977,  0.75601343,  0.75271611, 0.72295458,  0.65016935,  0.62013543,  0.58835745])

LS_R2_pos = np.array(LS_R2_pos)
LS_R2_vel = np.array(LS_R2_vel)

LS_R2_pos_mean = np.mean(LS_R2_pos, axis=0)
LS_R2_pos_std = np.std(LS_R2_pos, axis=0)

LS_R2_vel_mean = np.mean(LS_R2_vel, axis=0)
LS_R2_vel_std = np.std(LS_R2_vel, axis=0)

# %%
R_ind_pos = np.array([0.408, 0.430, 0.451, 0.500, 0.467])
R_ind_pos_mean = np.mean(R_ind_pos)
R_ind_pos_std = np.std(R_ind_pos)

fig_LS_len=plt.figure()
plt.errorbar(x, LS_R2_pos_mean, yerr=LS_R2_pos_std, fmt='.k', capsize=3,label='baseline LSTM')
plt.errorbar([12.5],R_ind_pos_mean, yerr=R_ind_pos_std, fmt='.r',capsize=3,label='direction-specific LSTM')

plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.grid()
plt.legend()
plt.savefig('RS_effect_of_data_length/LSTM_SR_data_length_pos.png')
plt.savefig('RS_effect_of_data_length/LSTM_SR_data_length_pos.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
R_ind_vel = np.array([0.594, 0.591, 0.615, 0.646, 0.605])
R_ind_vel_mean = np.mean(R_ind_vel)
R_ind_vel_std = np.std(R_ind_vel)


fig_LS_len=plt.figure()
plt.errorbar(x, LS_R2_vel_mean, yerr=LS_R2_vel_std, fmt='.k', capsize=3,label='baseline LSTM')
#plt.plot(x, ind, 'r',label='avg. ind. targets decoder')
plt.errorbar([12.5],R_ind_vel_mean, yerr=R_ind_vel_std, fmt='.r',capsize=3,label='direction-specific LSTM')
plt.xlabel('Percentage of data used [%]')
#plt.title('FFNN: R2 vs % of data used (Velocity)')
plt.grid()
plt.ylabel('Prediction Accuracy ($R^2$)')
plt.legend()
plt.savefig('RS_effect_of_data_length/LSTM_SR_data_length_vel.png')
plt.savefig('RS_effect_of_data_length/LSTM_SR_data_length_vel.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
